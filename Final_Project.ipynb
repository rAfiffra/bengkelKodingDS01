# %% [markdown]
# ##Mount gDrive

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/Bengkel Coding Data Saince/Final Project')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Koneksikan ke google drive untuk penyimpanan dataset danjuga .jpynb

# %% [markdown]
# ##import Libarry|

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from collections import Counter
from sklearn.preprocessing import StandardScaler


# Konfigurasi agar visualisasi lebih rapi
sns.set(style='whitegrid')
plt.rcParams["figure.figsize"] = (10, 6)

# %% [markdown]
# Import libary yang digunakan untuk mengolah dan mengvisualisasikan data set beserta pemodelanya

# %% [markdown]
# ##import dataset

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Bengkel Coding Data Saince/Final Project/ObesityDataSet.csv')

# %%
df.head()
# Out:
#   Age  Gender Height Weight        CALC FAVC FCVC NCP  SCC SMOKE CH2O  \
# 0  21  Female   1.62     64          no   no    2   3   no    no    2
# 1  21  Female   1.52     56   Sometimes   no    3   3  yes   yes    3
# 2  23    Male    1.8     77  Frequently   no    2   3   no    no    2
# 3  27    Male    1.8     87  Frequently   no    3   3   no    no    2
# 4  22    Male   1.78   89.8   Sometimes   no    2   1   no    no    2
#
#   family_history_with_overweight FAF TUE       CAEC                 MTRANS  \
# 0                            yes   0   1  Sometimes  Public_Transportation
# 1                            yes   3   0  Sometimes  Public_Transportation
# 2                            yes   2   1  Sometimes  Public_Transportation
# 3                             no   2   0  Sometimes                Walking
# 4                             no   0   0  Sometimes  Public_Transportation
#
#             NObeyesdad
# 0        Normal_Weight
# 1        Normal_Weight
# 2        Normal_Weight
# 3   Overweight_Level_I
# 4  Overweight_Level_II

# %%
df.tail()
# Out:
#             Age  Gender    Height      Weight       CALC FAVC FCVC NCP SCC  \
# 2106  20.976842  Female   1.71073  131.408528  Sometimes  yes    3   3  no
# 2107  21.982942  Female  1.748584  133.742943  Sometimes  yes    3   3  no
# 2108  22.524036  Female  1.752206  133.689352  Sometimes  yes    3   3  no
# 2109  24.361936  Female   1.73945  133.346641  Sometimes  yes    3   3  no
# 2110  23.664709  Female  1.738836  133.472641  Sometimes  yes    3   3  no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 2106    no  1.728139                            yes  1.676269  0.906247
# 2107    no   2.00513                            yes   1.34139   0.59927
# 2108    no  2.054193                            yes  1.414209  0.646288
# 2109    no  2.852339                            yes  1.139107  0.586035
# 2110    no  2.863513                            yes  1.026452  0.714137
#
#            CAEC                 MTRANS        NObeyesdad
# 2106  Sometimes  Public_Transportation  Obesity_Type_III
# 2107  Sometimes  Public_Transportation  Obesity_Type_III
# 2108  Sometimes  Public_Transportation  Obesity_Type_III
# 2109  Sometimes  Public_Transportation  Obesity_Type_III
# 2110  Sometimes  Public_Transportation  Obesity_Type_III

# %%
df.dtypes
# Out:
# Age                               object
# Gender                            object
# Height                            object
# Weight                            object
# CALC                              object
# FAVC                              object
# FCVC                              object
# NCP                               object
# SCC                               object
# SMOKE                             object
# CH2O                              object
# family_history_with_overweight    object
# FAF                               object
# TUE                               object
# CAEC                              object
# MTRANS                            object
# NObeyesdad                        object
# dtype: object

# %% [markdown]
# #1 Exploratory Data Analysis (EDA)

# %% [markdown]
# ##Dataset Information

# %%
# Display general information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             2097 non-null   object
#  1   Gender                          2102 non-null   object
#  2   Height                          2099 non-null   object
#  3   Weight                          2100 non-null   object
#  4   CALC                            2106 non-null   object
#  5   FAVC                            2100 non-null   object
#  6   FCVC                            2103 non-null   object
#  7   NCP                             2099 non-null   object
#  8   SCC                             2101 non-null   object
#  9   SMOKE                           2106 non-null   object
#  10  CH2O                            2105 non-null   object
#  11  family_history_with_overweight  2098 non-null   object
#  12  FAF                             2103 non-null   object
#  13  TUE                             2102 non-null   object
#  14  CAEC                            2100 non-null   object
#  15  MTRANS                          2105 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: object(17)
# memory usage: 280.5+ KB

# %%
# Display the shape of the dataset
df.shape
# Out:
# (2111, 17)

# %%
# Display descriptive statistics
df.describe()
# Out:
#          Age Gender Height Weight       CALC  FAVC  FCVC   NCP   SCC SMOKE  \
# count   2097   2102   2099   2100       2106  2100  2103  2099  2101  2106
# unique  1394      3   1562   1518          5     3   808   637     3     3
# top       18   Male    1.7     80  Sometimes   yes     3     3    no    no
# freq     124   1056     58     58       1386  1844   647  1183  1997  2054
#
#         CH2O family_history_with_overweight   FAF   TUE       CAEC  \
# count   2105                           2098  2103  2102       2100
# unique  1263                              3  1186  1130          5
# top        2                            yes     0     0  Sometimes
# freq     441                           1705   404   552       1747
#
#                        MTRANS      NObeyesdad
# count                    2105            2111
# unique                      6               7
# top     Public_Transportation  Obesity_Type_I
# freq                     1572             351

# %% [markdown]
# ##Cek Missing Values, Unique Values, & Cek Data Duplikat

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Age                               14
# Gender                             9
# Height                            12
# Weight                            11
# CALC                               5
# FAVC                              11
# FCVC                               8
# NCP                               12
# SCC                               10
# SMOKE                              5
# CH2O                               6
# family_history_with_overweight    13
# FAF                                8
# TUE                                9
# CAEC                              11
# MTRANS                             6
# NObeyesdad                         0
# dtype: int64

# %%
# Check for unique values in each column
categorical_cols = df.select_dtypes(include='object').columns
df[categorical_cols].nunique()
# Out:
# Age                               1394
# Gender                               3
# Height                            1562
# Weight                            1518
# CALC                                 5
# FAVC                                 3
# FCVC                               808
# NCP                                637
# SCC                                  3
# SMOKE                                3
# CH2O                              1263
# family_history_with_overweight       3
# FAF                               1186
# TUE                               1130
# CAEC                                 5
# MTRANS                               6
# NObeyesdad                           7
# dtype: int64

# %%
# Check for duplicate
df.duplicated().sum()
# Out:
# np.int64(18)

# %% [markdown]
# ##Distribusi Target dan Boxplot untuk Deteksi Outlier

# %%
# Visualisasi distribusi kelas target obesitas
sns.countplot(data=df, x='NObeyesdad', order=df['NObeyesdad'].value_counts().index)
plt.xticks(rotation=45)
plt.title('Distribusi Target - Tingkat Obesitas')
plt.show()

# %%
# Boxplot untuk mendeteksi outlier pada fitur numerik

# Re-calculate numeric_cols to ensure it's up-to-date
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Check if there are any numeric columns before attempting to plot
if len(numeric_cols) > 0:
    df[numeric_cols].plot(kind='box', subplots=True, layout=(3, 3), figsize=(15, 10), sharex=False)
    plt.tight_layout()
    plt.show()
else:
    print("No numeric columns found in the DataFrame to plot.")
# Out:
# No numeric columns found in the DataFrame to plot.

# %% [markdown]
# ## Cek  Keseimbangan Data

# %%
# Check the balance of the target variable
target_counts = df['NObeyesdad'].value_counts()

plt.figure(figsize=(18, 7))
sns.barplot(x=target_counts.index, y=target_counts.values)
plt.title('Balance of Target Variable (NObeyesdad)')
plt.xlabel('Obesity Level')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##Deteksi Outlier Menggunakan Boxplot

# %%
# Boxplot for Height and Weight
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(x=df['Height'])
plt.title('Boxplot of Height')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['Weight'])
plt.title('Boxplot of Weight')

plt.show()

# %% [markdown]
# ##Kesimpulan

# %% [markdown]
# Kesimpulan dari EDA:
# 1. Dataset memiliki 2111 baris dan 17 kolom.
# 2. Terdapat 150 missing values di dataset.
# 3. Terdapat 18 duplikat data.
# 4. Target variable 'NObeyesdad' memiliki distribusi yang tidak seimbang, terlihat dari Outlayernya

# %% [markdown]
# #2 Preprocessing Data

# %% [markdown]
# ##Ubah Tipe Data ke Numerik

# %%
# Melihat tipe data awal dari dataset
df.dtypes
# Out:
# Age                               object
# Gender                            object
# Height                            object
# Weight                            object
# CALC                              object
# FAVC                              object
# FCVC                              object
# NCP                               object
# SCC                               object
# SMOKE                             object
# CH2O                              object
# family_history_with_overweight    object
# FAF                               object
# TUE                               object
# CAEC                              object
# MTRANS                            object
# NObeyesdad                        object
# dtype: object

# %%
# Konversi kolom numerik yang masih berupa string ke float
numeric_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# Tampilkan beberapa baris untuk memastikan perubahan berhasil
df[numeric_cols].head()
# Out:
#     Age  Height  Weight  FCVC  NCP  CH2O  FAF  TUE
# 0  21.0    1.62    64.0   2.0  3.0   2.0  0.0  1.0
# 1  21.0    1.52    56.0   3.0  3.0   3.0  3.0  0.0
# 2  23.0    1.80    77.0   2.0  3.0   2.0  2.0  1.0
# 3  27.0    1.80    87.0   3.0  3.0   2.0  2.0  0.0
# 4  22.0    1.78    89.8   2.0  1.0   2.0  0.0  0.0

# %%
# Daftar kolom biner
binary_cols = ['FAVC', 'SCC', 'SMOKE', 'family_history_with_overweight']

# Ubah nilai 'yes' menjadi 1 dan 'no' menjadi 0
df[binary_cols] = df[binary_cols].replace({'yes': 1, 'no': 0})

# Cek hasil
df[binary_cols].head()
# Out:
#   FAVC SCC SMOKE family_history_with_overweight
# 0    0   0     0                              1
# 1    0   1     1                              1
# 2    0   0     0                              1
# 3    0   0     0                              0
# 4    0   0     0                              0

# %%
# Definisikan urutan ordinal
calc_order = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}
caec_order = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}

# Mapping
df['CALC'] = df['CALC'].map(calc_order)
df['CAEC'] = df['CAEC'].map(caec_order)

# Cek hasil
df[['CALC', 'CAEC']].head()
# Out:
#    CALC  CAEC
# 0   0.0   1.0
# 1   1.0   1.0
# 2   2.0   1.0
# 3   2.0   1.0
# 4   1.0   1.0

# %%
# One-hot encoding pada kolom MTRANS
df = pd.get_dummies(df, columns=['MTRANS'], prefix='MTRANS')

# Cek hasil
df.filter(like='MTRANS').head()
# Out:
#    MTRANS_?  MTRANS_Automobile  MTRANS_Bike  MTRANS_Motorbike  \
# 0     False              False        False             False
# 1     False              False        False             False
# 2     False              False        False             False
# 3     False              False        False             False
# 4     False              False        False             False
#
#    MTRANS_Public_Transportation  MTRANS_Walking
# 0                          True           False
# 1                          True           False
# 2                          True           False
# 3                         False            True
# 4                          True           False

# %%
# Encode target
le = LabelEncoder()
df['NObeyesdad'] = le.fit_transform(df['NObeyesdad'])

# Tampilkan label unik setelah encoding
df['NObeyesdad'].unique()
# Out:
# array([1, 5, 6, 2, 0, 3, 4])

# %%
# Periksa kembali tipe data setelah konversi
df.dtypes
# Out:
# Age                               float64
# Gender                             object
# Height                            float64
# Weight                            float64
# CALC                              float64
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# SCC                                object
# SMOKE                              object
# CH2O                              float64
# family_history_with_overweight     object
# FAF                               float64
# TUE                               float64
# CAEC                              float64
# NObeyesdad                          int64
# MTRANS_?                             bool
# MTRANS_Automobile                    bool
# MTRANS_Bike                          bool
# MTRANS_Motorbike                     bool
# MTRANS_Public_Transportation         bool
# MTRANS_Walking                       bool
# dtype: object

# %%
# Visualisasi jumlah tipe data sebelum dan sesudah

# Hitung tipe data sekarang
type_counts = df.dtypes.value_counts()

# Visualisasi
type_counts.plot(kind='bar', color='skyblue')
plt.title('Distribusi Tipe Data Setelah Konversi')
plt.xlabel('Tipe Data')
plt.ylabel('Jumlah Kolom')
plt.xticks(rotation=0)
plt.show()

# %%
# Korelasi antar fitur numerik
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title('Korelasi Antar Fitur Numerik')
plt.show()

# %% [markdown]
# ##Handling Missing Values & Duplikasi

# %%
df.replace('?', np.nan, inplace=True)
# Out:
# <ipython-input-59-f88d3956a9cb>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace('?', np.nan, inplace=True)

# %%
# Pastikan tidak ada missing values lagi
df.isnull().sum()
# Out:
# Age                               22
# Gender                            22
# Height                            22
# Weight                            19
# CALC                              20
# FAVC                              22
# FCVC                              18
# NCP                               22
# SCC                               18
# SMOKE                             13
# CH2O                              15
# family_history_with_overweight    23
# FAF                               19
# TUE                               15
# CAEC                              18
# NObeyesdad                         0
# MTRANS_?                           0
# MTRANS_Automobile                  0
# MTRANS_Bike                        0
# MTRANS_Motorbike                   0
# MTRANS_Public_Transportation       0
# MTRANS_Walking                     0
# dtype: int64

# %%
# Kolom numerik yang mengandung missing values
numerik_missing = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# Konversi kembali kolom numerik yang mungkin masih berupa string ke float
# errors='coerce' akan mengganti nilai yang tidak bisa dikonversi menjadi NaN
for col in numerik_missing:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Sekarang, imputasi median seharusnya berfungsi karena kolom sudah numerik
for col in numerik_missing:
    # Cek jika masih ada NaN setelah konversi, lalu imputasi median
    if df[col].isnull().any():
        df[col] = df[col].fillna(df[col].median())

# Optional: Periksa kembali tipe data dan missing values setelah imputasi
print("Tipe data setelah konversi dan imputasi:")
print(df[numerik_missing].dtypes)
print("\nJumlah missing values setelah imputasi:")
print(df[numerik_missing].isnull().sum())
# Out:
# Tipe data setelah konversi dan imputasi:
# Age       float64
# Height    float64
# Weight    float64
# FCVC      float64
# NCP       float64
# CH2O      float64
# FAF       float64
# TUE       float64
# dtype: object
#
# Jumlah missing values setelah imputasi:
# Age       0
# Height    0
# Weight    0
# FCVC      0
# NCP       0
# CH2O      0
# FAF       0
# TUE       0
# dtype: int64

# %%
# Kolom ordinal dengan missing
ordinal_missing = ['CALC', 'CAEC']

# Imputasi mode
for col in ordinal_missing:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# Kolom biner dengan missing
biner_missing = ['FAVC', 'SCC', 'SMOKE', 'family_history_with_overweight']

for col in biner_missing:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# Drop Gender karena missing terlalu tinggi dan tidak terlalu penting
df.drop(columns=['Gender'], inplace=True)

# %%
# Final check
df.isnull().sum()
# Out:
# Age                               0
# Height                            0
# Weight                            0
# CALC                              0
# FAVC                              0
# FCVC                              0
# NCP                               0
# SCC                               0
# SMOKE                             0
# CH2O                              0
# family_history_with_overweight    0
# FAF                               0
# TUE                               0
# CAEC                              0
# NObeyesdad                        0
# MTRANS_?                          0
# MTRANS_Automobile                 0
# MTRANS_Bike                       0
# MTRANS_Motorbike                  0
# MTRANS_Public_Transportation      0
# MTRANS_Walking                    0
# dtype: int64

# %%
# Cek jumlah duplikasi
print("Jumlah duplikasi:", df.duplicated().sum())

# Hapus jika ada
df.drop_duplicates(inplace=True)
# Out:
# Jumlah duplikasi: 20

# %% [markdown]
# ##Outlier

# %%
numeric_cols = df.select_dtypes(include='number').columns.tolist()

# Simpan dataframe sebelum menghapus outlier
df_before = df.copy()

# Hitung IQR dan filter outlier
Q1 = df[numeric_cols].quantile(0.25)
Q3 = df[numeric_cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[numeric_cols] < (Q1 - 1.5 * IQR)) | (df[numeric_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# Visualisasi boxplot sebelum dan sesudah
fig, axes = plt.subplots(len(numeric_cols), 2, figsize=(12, 5*len(numeric_cols)))

for i, col in enumerate(numeric_cols):
    # Boxplot sebelum
    sns.boxplot(x=df_before[col], ax=axes[i, 0])
    axes[i, 0].set_title(f'Before Removing Outliers - {col}')

    # Boxplot setelah
    sns.boxplot(x=df[col], ax=axes[i, 1])
    axes[i, 1].set_title(f'After Removing Outliers - {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluasi Fitur yang Tidak Digunakan (Feature Selection)

# %%
# Encode target jika kategorikal
if df['NObeyesdad'].dtype == 'object':
    le = LabelEncoder()
    df['NObeyesdad_enc'] = le.fit_transform(df['NObeyesdad'])
else:
    # If NObeyesdad is already numeric, just use it
    df['NObeyesdad_enc'] = df['NObeyesdad']

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=np.number)

# Hitung korelasi terhadap target yang sudah di-encode
# Ensure 'NObeyesdad_enc' is in the numeric_df before calculating correlation
if 'NObeyesdad_enc' in numeric_df.columns:
    correlation = numeric_df.corr()['NObeyesdad_enc'].drop('NObeyesdad_enc', errors='ignore').sort_values(ascending=False)
else:
    # Handle case where NObeyesdad_enc might not be considered numeric (unlikely after assignment)
    # Or if the original NObeyesdad was not numeric and the encoding failed.
    # For robustness, we can try to force numeric or add a print statement.
    print("Warning: 'NObeyesdad_enc' column not found or not numeric in the selected DataFrame.")
    # As a fallback, try converting NObeyesdad_enc to numeric explicitly if it exists
    if 'NObeyesdad_enc' in df.columns:
         df['NObeyesdad_enc'] = pd.to_numeric(df['NObeyesdad_enc'], errors='coerce')
         numeric_df = df.select_dtypes(include=np.number)
         if 'NObeyesdad_enc' in numeric_df.columns:
              correlation = numeric_df.corr()['NObeyesdad_enc'].drop('NObeyesdad_enc', errors='ignore').sort_values(ascending=False)
         else:
             print("Error: 'NObeyesdad_enc' could not be made numeric.")
             correlation = pd.Series() # Empty series to avoid further errors


# Visualisasi Barplot - only proceed if correlation is not empty
if not correlation.empty:
    plt.figure(figsize=(10,6))
    sns.barplot(x=correlation.values, y=correlation.index, palette='coolwarm')
    plt.title('Korelasi Fitur terhadap Target NObeyesdad')
    plt.xlabel('Korelasi Pearson')
    plt.ylabel('Fitur')
    plt.show()
else:
    print("No numeric features available to plot correlation.")
# Out:
# <ipython-input-68-2e104aae2b61>:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=correlation.values, y=correlation.index, palette='coolwarm')

# %% [markdown]
# ##Cek Keseimbangan Target

# %%
sns.countplot(x=df['NObeyesdad'])
plt.xticks(rotation=45)
plt.title("Distribusi Target Setelah Preprocessing")
plt.show()

# %%
# Pisahkan fitur dan target
X = df.drop('NObeyesdad', axis=1)
y = df['NObeyesdad']

# --- Tambahkan langkah ini untuk memastikan semua kolom di X numerik ---
# Identifikasi kolom non-numerik yang mungkin tersisa
non_numeric_cols_X = X.select_dtypes(include='object').columns

# Lakukan one-hot encoding pada kolom non-numerik yang tersisa di X
if len(non_numeric_cols_X) > 0:
    print(f"Columns in X that are still non-numeric: {list(non_numeric_cols_X)}")
    # Gunakan pd.get_dummies untuk mengonversi kolom objek yang tersisa
    X = pd.get_dummies(X, columns=non_numeric_cols_X, drop_first=True) # drop_first=True untuk menghindari multicollinearity
    print("Applied one-hot encoding to remaining non-numeric columns.")

# Verifikasi tipe data setelah one-hot encoding (opsional tapi disarankan)
# print("Data types of X after potential one-hot encoding:")
# print(X.dtypes)
# --- Akhir dari penambahan langkah verifikasi dan encoding ---


# SMOTE untuk mengatasi imbalance
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X_bal, y_bal = smote.fit_resample(X, y)

# Cek hasil distribusi setelah SMOTE
from collections import Counter
print("Distribusi Kelas Setelah SMOTE:", Counter(y_bal))
# Out:
# Distribusi Kelas Setelah SMOTE: Counter({1: 311, 6: 311, 5: 311, 2: 311, 0: 311, 4: 311, 3: 311})

# %%
# Visualisasi distribusi target asli
plt.figure(figsize=(10,4))
plt.subplot(1, 2, 1)
sns.countplot(x=df['NObeyesdad'])
plt.xticks(rotation=45)
plt.title("Distribusi Target Sebelum SMOTE")

# Buat DataFrame baru hasil SMOTE supaya bisa plot
df_bal = pd.DataFrame(X_bal, columns=X.columns)
df_bal['NObeyesdad'] = y_bal

# Visualisasi distribusi target setelah SMOTE
plt.subplot(1, 2, 2)
sns.countplot(x=df_bal['NObeyesdad'])
plt.xticks(rotation=45)
plt.title("Distribusi Target Setelah SMOTE")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Normalisasi

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_bal)

# %%
# Normalisasi
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_bal)

# Create a DataFrame from the scaled data for plotting comparison
# Use the column names from the original X DataFrame
df_after = pd.DataFrame(X_scaled, columns=X.columns)

features = X.columns[:3]

for feature in features:
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    # Use df_before for the 'before' plot (this was already defined correctly)
    sns.histplot(df_before[feature], bins=30, color='skyblue', kde=True) # Use histplot for better visualization with kde
    plt.title(f'{feature} Sebelum Scaling')
    plt.xlabel('Nilai')
    plt.ylabel('Frekuensi')

    plt.subplot(1,2,2)
    # Use the newly created df_after for the 'after' plot
    sns.histplot(df_after[feature], bins=30, color='salmon', kde=True) # Use histplot for better visualization with kde
    plt.title(f'{feature} Setelah Scaling')
    plt.xlabel('Nilai Z-Score') # Update x-label as it's now Z-scores
    plt.ylabel('Frekuensi')


    plt.tight_layout()
    plt.show()

# %% [markdown]
# KESIMPULAN PREPROCESSING:
# 1. Seluruh data kategorikal telah dikonversi ke numerik dengan benar.
# 2. Tidak ditemukan missing values atau duplikasi data.
# 3. Outlier telah dihapus menggunakan metode IQR.
# 4. Semua fitur tetap digunakan karena saling melengkapi dan korelasi bervariasi.
# 5. Ketidakseimbangan data ditangani dengan SMOTE untuk menjaga performa model.
# 6. Data telah dinormalisasi menggunakan StandardScaler.

# %% [markdown]
# #.

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# ###cek data hilang

# %%
print("Jumlah missing values:")
print(df.isnull().sum())

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ###Hapus Missing Values (jika ada)

# %%
df = df.dropna()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ###Cek data Duplikasi

# %%
print(f"Duplikasi ditemukan: {df.duplicated().sum()} baris")
df = df.drop_duplicates()

# %% [markdown]
# setelah ditemukan sebanyak 24 baris maka akan di hapus data yg duplikat itu

# %% [markdown]
# ###Cek Tipe Data

# %%
print(df.dtypes)

# %% [markdown]
# ###Buatkan label untuk mempermudah pembacaan pada dataset

# %%
df.head()

# %%
df.columns=["age","workclass","fnlwgt","education","educationnum","maritalstatus","occupation","relationship","race","sex","capitalgain",
                 "capitalloss","hoursperweek","nativecountry","income"]

# %%
df.head()

# %% [markdown]
# ###Cek Outlier (menggunakan Z-score)

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
z_scores = np.abs(zscore(df[numeric_cols]))


fig, axes = plt.subplots(1, 2, figsize=(14, 7))
sns.boxplot(data=df[numeric_cols], ax=axes[0])
axes[0].set_title('Distribusi Sebelum Penghapusan Outlier')


df_cleaned = df[(z_scores < 3).all(axis=1)]
sns.boxplot(data=df_cleaned[numeric_cols], ax=axes[1])
axes[1].set_title('Distribusi Setelah Penghapusan Outlier')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###Encoding data bertipe Kategorikal

# %%
le = LabelEncoder()
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# %%
print(df.dtypes)

# %% [markdown]
# ###Oversampling (SMOTE)

# %%
X = df.drop('income', axis=1)
y = df['income']

# %%
print("Distribusi sebelum SMOTE:")
print(y.value_counts())

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("Distribusi setelah SMOTE:")
print(y_resampled.value_counts())

# %% [markdown]
# ###Standardisasi

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_resampled)

# %%
col_index = 0
col_name = X.columns[col_index]

plt.figure(figsize=(12, 5))

# %%
#sebelum
plt.subplot(1, 2, 1)
sns.histplot(X_resampled.iloc[:, col_index], kde=True, color='skyblue')
plt.title(f'📊 Sebelum Standardisasi - {col_name}')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi')

# %%
#sesudah
plt.subplot(1, 2, 2)
sns.histplot(X_scaled[:, col_index], kde=True, color='salmon')
plt.title(f'📈 Setelah Standardisasi - {col_name}')
plt.xlabel('Nilai Z-Score')
plt.ylabel('Frekuensi')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Split dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_resampled, test_size=0.2, random_state=42)

# %%
X_train

# %%
y_train

# %% [markdown]
# ##Modeling & Evaluasi

# %% [markdown]
# ###Melatih dan Evaluasi Model

# %%
#model yang digunakan sebagai patokan dan pemprosesan
models = {
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "KNN": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "SVM": SVC()
}

# %% [markdown]
# melatih model

# %%
results = {}

for name, model in models.items():
    start = time.time()
    model.fit(X_train, y_train)
    training_time = time.time() - start

    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, output_dict=True)
    cm = confusion_matrix(y_test, y_pred)

    results[name] = {
        "report": report,
        "confusion_matrix": cm,
        "training_time": training_time
    }

# %%
for name, result in results.items():
    print(f"\n Model: {name}")
    print(f"Training Time: {training_time:.4f} seconds")
    print(classification_report(y_test, y_pred))

    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(f"Confusion Matrix - {name}")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# %% [markdown]
# ###Ringkasan Hasil Evaluasi

# %%
summary = []
for name, res in results.items():
    report = res["report"]
    summary.append({
        "Model": name,
        "Accuracy": report["accuracy"],
        "Precision": report["1"]["precision"],
        "Recall": report["1"]["recall"],
        "F1-Score": report["1"]["f1-score"],
        "Training Time": res["training_time"]
    })

summary_df = pd.DataFrame(summary).sort_values(by="Accuracy", ascending=False)
print(summary_df)

# %% [markdown]
# ###Kesimpulan dan Rekomendasi

# %%
best_model = summary_df.iloc[0]
print("\n Model Terbaik:")
print(best_model)
